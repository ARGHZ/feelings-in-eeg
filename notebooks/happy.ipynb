# %%
# %matplotlib inline
import config as general_config
import json

from networkx.readwrite import json_graph
from digraph import draw_graph

emotion = 'happy'

# %%
json_file_path = general_config.DATA_DIR + '/graphs/by_emotion/' + emotion + '_delta.json'
with open(json_file_path) as json_file:
    data = json.load(json_file)

G = json_graph.node_link_graph(data)

draw_graph(G, '')

# %%
json_file_path = general_config.DATA_DIR + '/graphs/by_emotion/' + emotion + '_theta.json'
with open(json_file_path) as json_file:
    data = json.load(json_file)

G = json_graph.node_link_graph(data)

draw_graph(G, '')

# %%
json_file_path = general_config.DATA_DIR + '/graphs/by_emotion/' + emotion + '_alpha.json'
with open(json_file_path) as json_file:
    data = json.load(json_file)

G = json_graph.node_link_graph(data)

draw_graph(G, '')

# %%
json_file_path = general_config.DATA_DIR + '/graphs/by_emotion/' + emotion + '_beta.json'
with open(json_file_path) as json_file:
    data = json.load(json_file)

G = json_graph.node_link_graph(data)

draw_graph(G, '')

# %%
json_file_path = general_config.DATA_DIR + '/graphs/by_emotion/' + emotion + '_gamma.json'
with open(json_file_path) as json_file:
    data = json.load(json_file)

G = json_graph.node_link_graph(data)

draw_graph(G, '')
